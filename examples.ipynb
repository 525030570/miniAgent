# %%
# %run src/main.py
# Out:
# 正在测试模型能否正常调用...
# ▌ MiniAgent初始化完成，欢迎使用！
# 你好，我是电工小陈制作的MiniAgent，有什么需要帮助的？
# **MiniAgent**:我有多种能力，可以帮助你完成各种任务，包括但不限于以下方面：
#
# ### 1. **编程与代码执行**
#    - **Python代码执行**：可以运行Python代码并返回结果，支持数据处理、算法实现等（非绘图类任务）。
#    - **数据可视化**：可以生成图表（如折线图、柱状图、散点图等），并展示图像。
#    - **SQL查询**：可以连接MySQL数据库，执行SQL查询并返回结果。
#    - **数据提取**：可以从MySQL数据库中提取数据表到Python环境中。
#
# ### 2. **数据处理与分析**
#    - 支持数据清洗、统计分析、机器学习模型训练等任务。
#    - 可以处理结构化数据（如DataFrame）或非结构化数据。
#
# ### 3. **联网搜索**
#    - **常规搜索**：可以通过谷歌搜索获取问题的答案，并为你总结信息。
#    - **GitHub搜索**：可以搜索GitHub上的项目，并为你介绍相关内容。
#
# ### 4. **问题解答与知识分享**
#    - 可以回答各种领域的问题，包括技术、科学、生活等。
#    - 提供学习资源、教程或建议。
#
# ### 5. **工具集成**
#    - 支持与其他工具或API的集成，扩展功能范围。
#
# ### 6. **个性化帮助**
#    - 根据你的需求提供定制化的解决方案，比如学习计划、代码调试等。
#
# 如果你有任何具体的需求或问题，可以直接告诉我，我会尽力帮助你！
# 文件已成功保存到：d:\大模型项目\mini_manus\miniAgent\research_task\请介绍一下你有哪....md

# %%
# %run src/main.py
# Out:
# 正在测试模型能否正常调用...
# ▌ MiniAgent初始化完成，欢迎使用！
# 你好，我是电工小陈制作的MiniAgent，有什么需要帮助的？
# 即将执行以下代码：
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # 模拟上海某日24小时的电力负荷数据（单位：兆瓦）
# hours = np.arange(24)
# power_load = np.array([500, 480, 460, 450, 470, 600, 800, 1000, 1200, 1300, 1400, 1500,
#                        1600, 1550, 1500, 1450, 1400, 1300, 1200, 1100, 900, 700, 600, 550])
#
# # 创建图形
# fig, ax = plt.subplots(figsize=(10, 6))
# ax.plot(hours, power_load, marker='o', linestyle='-', color='b')
# ax.set_title('上海某日电力负荷曲线图')
# ax.set_xlabel('时间（小时）')
# ax.set_ylabel('电力负荷（兆瓦）')
# ax.grid(True)
#
# # 设置x轴刻度为24小时
# ax.set_xticks(np.arange(0, 24, 1))
#
# fig = plt.gcf()
# ```
# 正在调用fig_inter工具运行Python代码...
# 代码已顺利执行，正在进行结果梳理...
# **MiniAgent**:以下是根据模拟数据绘制的上海某日电力负荷曲线图：
#
# ![上海某日电力负荷曲线图](pics/fig.png)
#
# 图中展示了24小时内电力负荷的变化情况，单位为兆瓦（MW）。如果需要调整数据或图表样式，请告诉我！
# 文件已成功保存到：d:\大模型项目\mini_manus\miniAgent\research_task\请模拟数据绘制上....md

# %%
# %run src/main.py
# Out:
# 正在测试模型能否正常调用...
# ▌ MiniAgent初始化完成，欢迎使用！
# 你好，我是电工小陈制作的MiniAgent，有什么需要帮助的？
# **MiniAgent**:你好！请问有什么可以帮您的吗？
# 文件已成功保存到：d:\大模型项目\mini_manus\miniAgent\research_task\....md
# 正在接入谷歌搜索，查找和问题相关的答案...
# 正在检索：https://www.ibm.com/cn-zh/about
# 网页标题: IBM 公司简介 | IBM 介绍
# 正在检索：https://zh.wikipedia.org/zh-hans/IBM
# 网页标题: IBM - 维基百科，自由的百科全书
# **MiniAgent**:IBM（国际商业机器公司）是一家全球领先的科技和咨询公司，总部位于美国纽约州阿蒙克市。以下是关于IBM的一些关键信息：
#
# ### 1. **公司使命**
# IBM的使命是通过技术创新推动社会进步，致力于通过商业道德、环保承诺和负责任的技术在全球范围内产生积极影响。
#
# ### 2. **业务领域**
# IBM的业务涵盖多个领域，包括：
# - **咨询**：为企业提供数字化转型和业务优化服务。
# - **软件**：提供人工智能（AI）、混合云解决方案等。
# - **基础架构**：包括服务器、存储和云计算技术。
# - **生态系统**：与合作伙伴共同设计端到端解决方案。
# - **Red Hat**：提供开源解决方案以提高生产力和降低成本。
#
# ### 3. **技术创新**
# IBM在技术领域的贡献包括：
# - **大型机革命**：1964年推出的System/360。
# - **个人电脑**：1981年发布IBM PC。
# - **人工智能**：2011年Watson在《Jeopardy》节目中获胜。
# - **量子计算**：IBM在量子计算领域处于全球领先地位。
#
# ### 4. **全球影响**
# - **员工**：超过30万名员工遍布170多个国家。
# - **研究设施**：全球12个实验室，19个研究设施。
# - **可持续发展**：目标是到2030年实现温室气体净零排放。
#
# ### 5. **历史里程碑**
# ...
